# %%
import glob
import re

# %%
# %load_ext rpy2.ipython
# Out:
# /home/timp/miniconda3/envs/cpowgs/lib/python3.7/site-packages/rpy2/robjects/pandas2ri.py:14: FutureWarning: pandas.core.index is deprecated and will be removed in a future version.  The public classes are available in the top-level namespace.
#   from pandas.core.index import Index as PandasIndex

# %% [markdown]
# Ok - trying to use prokka - roary to make a pangenome
#
# Made a conda environment conda create --name cpowgs
# Then conda install -c conda-forge -c bioconda -c defaults prokka
# then
# conda config --add channels r
# conda config --add channels defaults
# conda config --add channels conda-forge
# conda config --add channels bioconda
# conda install roary
# then
# conda install jupyterlab (I know, wrong order)
# then
# conda install raxml
# then
# conda install snp-sites
# then
# conda install pandas

# %%
# %cd ~/Data/200404_trish/ecoli/
# Out:
# /mnt/d/Data/200404_trish/ecoli

# %% [markdown]
# ok - clean up the pilon assmeblies so that the headers don't have _pilon_ over and over and over

# %%
# !sed -i 's/_pilon//g' pilon/*fasta

# %% [markdown]
# Ok - I need to pull down the genbank files for Enterobacter cloacae: https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/025/565/GCF_000025565.1_ASM2556v1/GCF_000025565.1_ASM2556v1_genomic.gbff.gz
# E. Coli: https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/005/845/GCF_000005845.2_ASM584v2/GCF_000005845.2_ASM584v2_genomic.gbff.gz
# and K. Pneumo: https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/240/185/GCF_000240185.1_ASM24018v2/GCF_000240185.1_ASM24018v2_genomic.gbff.gz

# %%
# %mkdir refs
# %cd refs
# !wget https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/240/185/GCF_000240185.1_ASM24018v2/GCF_000240185.1_ASM24018v2_genomic.gbff.gz
# !gunzip *gz
# %mv *gbff ecoli_ref.gb
# %cd ..
# Out:
# /mnt/d/Data/200404_trish/ecoli/refs
# --2020-04-05 15:43:59--  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/240/185/GCF_000240185.1_ASM24018v2/GCF_000240185.1_ASM24018v2_genomic.gbff.gz
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.13, 2607:f220:41e:250::12
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.13|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4011962 (3.8M) [application/x-gzip]
# Saving to: ‘GCF_000240185.1_ASM24018v2_genomic.gbff.gz’
#
# GCF_000240185.1_ASM 100%[===================>]   3.83M  --.-KB/s    in 0.1s
#
# 2020-04-05 15:43:59 (33.5 MB/s) - ‘GCF_000240185.1_ASM24018v2_genomic.gbff.gz’ saved [4011962/4011962]
#
# /mnt/d/Data/200404_trish/ecoli

# %% [markdown]
# Ok - now prokka

# %%
# %rm -R prok
# %rm -R gff
# %mkdir gff
filelist=(glob.glob("pilon/*fasta"))
for myfile in filelist:
    tag=re.split('[\/\.]', myfile)[1]
    print(tag)
    # !prokka --quiet --protein refs/ecoli_ref.gb --outdir prok/$tag --genus Escherichia --usegenus --prefix $tag --locustag $tag $myfile 
    # %cp prok/$tag/*gff gff
# Out:
# ecoli_100
# [tbl2asn-forever] Found Prokka input, correcting dates in .gbf|.sqn files.
# [tbl2asn-forever] Correcting dates in prok/ecoli_100/ecoli_100.gbf
# [tbl2asn-forever] Correcting dates in prok/ecoli_100/ecoli_100.sqn
# [tbl2asn-forever] Dates changed from 01-JAN-2019 to 05-APR-2020
# ecoli_102
# [tbl2asn-forever] Found Prokka input, correcting dates in .gbf|.sqn files.
# [tbl2asn-forever] Correcting dates in prok/ecoli_102/ecoli_102.gbf
# [tbl2asn-forever] Correcting dates in prok/ecoli_102/ecoli_102.sqn
# [tbl2asn-forever] Dates changed from 01-JAN-2019 to 05-APR-2020
# ecoli_173
# [tbl2asn-forever] Found Prokka input, correcting dates in .gbf|.sqn files.
# [tbl2asn-forever] Correcting dates in prok/ecoli_173/ecoli_173.gbf
# [tbl2asn-forever] Correcting dates in prok/ecoli_173/ecoli_173.sqn
# [tbl2asn-forever] Dates changed from 01-JAN-2019 to 05-APR-2020
# ecoli_174
# [tbl2asn-forever] Found Prokka input, correcting dates in .gbf|.sqn files.
# [tbl2asn-forever] Correcting dates in prok/ecoli_174/ecoli_174.gbf
# [tbl2asn-forever] Correcting dates in prok/ecoli_174/ecoli_174.sqn
# [tbl2asn-forever] Dates changed from 01-JAN-2019 to 05-APR-2020
# ecoli_271
# [tbl2asn-forever] Found Prokka input, correcting dates in .gbf|.sqn files.
# [tbl2asn-forever] Correcting dates in prok/ecoli_271/ecoli_271.gbf
# [tbl2asn-forever] Correcting dates in prok/ecoli_271/ecoli_271.sqn
# [tbl2asn-forever] Dates changed from 01-JAN-2019 to 05-APR-2020
# ecoli_387
# [tbl2asn-forever] Found Prokka input, correcting dates in .gbf|.sqn files.
# [tbl2asn-forever] Correcting dates in prok/ecoli_387/ecoli_387.gbf
# [tbl2asn-forever] Correcting dates in prok/ecoli_387/ecoli_387.sqn
# [tbl2asn-forever] Dates changed from 01-JAN-2019 to 05-APR-2020
# ecoli_402
# [tbl2asn-forever] Found Prokka input, correcting dates in .gbf|.sqn files.
# [tbl2asn-forever] Correcting dates in prok/ecoli_402/ecoli_402.gbf
# [tbl2asn-forever] Correcting dates in prok/ecoli_402/ecoli_402.sqn
# [tbl2asn-forever] Dates changed from 01-JAN-2019 to 05-APR-2020
# ecoli_421
# [tbl2asn-forever] Found Prokka input, correcting dates in .gbf|.sqn files.
# [tbl2asn-forever] Correcting dates in prok/ecoli_421/ecoli_421.gbf
# [tbl2asn-forever] Correcting dates in prok/ecoli_421/ecoli_421.sqn
# [tbl2asn-forever] Dates changed from 01-JAN-2019 to 05-APR-2020
# ecoli_485
# [tbl2asn-forever] Found Prokka input, correcting dates in .gbf|.sqn files.
# [tbl2asn-forever] Correcting dates in prok/ecoli_485/ecoli_485.gbf
# [tbl2asn-forever] Correcting dates in prok/ecoli_485/ecoli_485.sqn
# [tbl2asn-forever] Dates changed from 01-JAN-2019 to 05-APR-2020
# ecoli_50
# [tbl2asn-forever] Found Prokka input, correcting dates in .gbf|.sqn files.
# [tbl2asn-forever] Correcting dates in prok/ecoli_50/ecoli_50.gbf
# [tbl2asn-forever] Correcting dates in prok/ecoli_50/ecoli_50.sqn
# [tbl2asn-forever] Dates changed from 01-JAN-2019 to 05-APR-2020
# ecoli_503
# [tbl2asn-forever] Found Prokka input, correcting dates in .gbf|.sqn files.
# [tbl2asn-forever] Correcting dates in prok/ecoli_503/ecoli_503.gbf
# [tbl2asn-forever] Correcting dates in prok/ecoli_503/ecoli_503.sqn
# [tbl2asn-forever] Dates changed from 01-JAN-2019 to 05-APR-2020
# ecoli_516
# [tbl2asn-forever] Found Prokka input, correcting dates in .gbf|.sqn files.
# [tbl2asn-forever] Correcting dates in prok/ecoli_516/ecoli_516.gbf
# [tbl2asn-forever] Correcting dates in prok/ecoli_516/ecoli_516.sqn
# [tbl2asn-forever] Dates changed from 01-JAN-2019 to 05-APR-2020
# ecoli_52
# [tbl2asn-forever] Found Prokka input, correcting dates in .gbf|.sqn files.
# [tbl2asn-forever] Correcting dates in prok/ecoli_52/ecoli_52.gbf
# [tbl2asn-forever] Correcting dates in prok/ecoli_52/ecoli_52.sqn
# [tbl2asn-forever] Dates changed from 01-JAN-2019 to 05-APR-2020
# ecoli_526
# [tbl2asn-forever] Found Prokka input, correcting dates in .gbf|.sqn files.
# [tbl2asn-forever] Correcting dates in prok/ecoli_526/ecoli_526.gbf
# [tbl2asn-forever] Correcting dates in prok/ecoli_526/ecoli_526.sqn
# [tbl2asn-forever] Dates changed from 01-JAN-2019 to 05-APR-2020
# ecoli_56
# [tbl2asn-forever] Found Prokka input, correcting dates in .gbf|.sqn files.
# [tbl2asn-forever] Correcting dates in prok/ecoli_56/ecoli_56.gbf
# [tbl2asn-forever] Correcting dates in prok/ecoli_56/ecoli_56.sqn
# [tbl2asn-forever] Dates changed from 01-JAN-2019 to 05-APR-2020
# ecoli_594
# [tbl2asn-forever] Found Prokka input, correcting dates in .gbf|.sqn files.
# [tbl2asn-forever] Correcting dates in prok/ecoli_594/ecoli_594.gbf
# [tbl2asn-forever] Correcting dates in prok/ecoli_594/ecoli_594.sqn
# [tbl2asn-forever] Dates changed from 01-JAN-2019 to 05-APR-2020
# ecoli_630
# [tbl2asn-forever] Found Prokka input, correcting dates in .gbf|.sqn files.
# [tbl2asn-forever] Correcting dates in prok/ecoli_630/ecoli_630.gbf
# [tbl2asn-forever] Correcting dates in prok/ecoli_630/ecoli_630.sqn
# [tbl2asn-forever] Dates changed from 01-JAN-2019 to 05-APR-2020
# ecoli_66
# [tbl2asn-forever] Found Prokka input, correcting dates in .gbf|.sqn files.
# [tbl2asn-forever] Correcting dates in prok/ecoli_66/ecoli_66.gbf
# [tbl2asn-forever] Correcting dates in prok/ecoli_66/ecoli_66.sqn
# [tbl2asn-forever] Dates changed from 01-JAN-2019 to 05-APR-2020

# %% [markdown]
# Ok - now let's try roary
#
# Roary says first https://github.com/microgenomics/tutorials/blob/master/pangenome.md
# you gotta organize the gff files

# %%
# !roary -i 95 -f pan -e -n -p 8 gff/*gff
# Out:
# Use of uninitialized value in require at /home/timp/miniconda3/envs/cpowgs/lib/site_perl/5.26.2/x86_64-linux-thread-multi/Encode.pm line 61.
#
# Please cite Roary if you use any of the results it produces:
#     Andrew J. Page, Carla A. Cummins, Martin Hunt, Vanessa K. Wong, Sandra Reuter, Matthew T. G. Holden, Maria Fookes, Daniel Falush, Jacqueline A. Keane, Julian Parkhill,
# 	"Roary: Rapid large-scale prokaryote pan genome analysis", Bioinformatics, 2015 Nov 15;31(22):3691-3693
#     doi: http://doi.org/10.1093/bioinformatics/btv421
# 	Pubmed: 26198102
#
# Use of uninitialized value in require at /home/timp/miniconda3/envs/cpowgs/lib/site_perl/5.26.2/x86_64-linux-thread-multi/Encode.pm line 61.
# Use of uninitialized value in require at (eval 931) line 1.

# %% [markdown]
# Counting snps from the multi-fa using snp-sites tool

# %%
# !snp-sites -v pan/core_gene_alignment.aln >pan/core_gene_alignment.vcf

# %%
# %%R
# library(tidyverse)
#
# vcfs=read_tsv("pan/core_gene_alignment.vcf", comment="##")
#
# ##ok - for each sample column, need to look at delta for all other sample columns, then sum to get that square on the table
# ##Interesting names are names(vcfs)[10:22]
#
# comp=as_data_frame(t(combn(names(vcfs[10:22]),2))) %>%
#     mutate(val=colSums(abs(vcfs[V1]-vcfs[V2])))
#
# comp=rbind(comp, data_frame(V1=comp$V2, V2=comp$V1, val=comp$val))
#
# write_csv(spread(comp, V2, val), "pan/core_gene_alignment_count.csv")
# Out:
# R[write to console]: Parsed with column specification:
# cols(
#   .default = col_double(),
#   ID = col_character(),
#   REF = col_character(),
#   ALT = col_character(),
#   QUAL = col_character(),
#   FILTER = col_character(),
#   INFO = col_character(),
#   FORMAT = col_character()
# )
#
# R[write to console]: See spec(...) for full column specifications.

# %% [markdown]
# Ok - that generated a pan genome and core alignment file which is already getting me close.  I then ran it in geneious, but let me take a guess and try to run in raxml
# some tips:
# -p is a random parsimony seed - to make sure analysis does the same thing
# -m GTRGAMMA - GTR GAMMA method
# -x is the rapid bootstrapping seed
# -N is the number of bootstrapops
# -f a says do rapid bootstrap

# %%
# %rm -R raxml
# %mkdir raxml
# %cd raxml
# !raxmlHPC-PTHREADS -T 6 -f a -m GTRGAMMA -p 53243 -x 72341 -s ../pan/core_gene_alignment.aln -N 100 -n testrapid.tree
# %cd ..
# Out:
# /mnt/d/Data/200404_trish/ecoli/raxml
#
# RAxML can't, parse the alignment file as phylip file
# it will now try to parse it as FASTA file
#
#
#
# Using BFGS method to optimize GTR rate parameters, to disable this specify "--no-bfgs"
#
#
# This is the RAxML Master Pthread
#
# This is RAxML Worker Pthread Number: 1
#
# This is RAxML Worker Pthread Number: 2
#
# This is RAxML Worker Pthread Number: 3
#
# This is RAxML Worker Pthread Number: 4
#
# This is RAxML Worker Pthread Number: 5
#
#
# This is RAxML version 8.2.12 released by Alexandros Stamatakis on May 2018.
#
# With greatly appreciated code contributions by:
# Andre Aberer      (HITS)
# Simon Berger      (HITS)
# Alexey Kozlov     (HITS)
# Kassian Kobert    (HITS)
# David Dao         (KIT and HITS)
# Sarah Lutteropp   (KIT and HITS)
# Nick Pattengale   (Sandia)
# Wayne Pfeiffer    (SDSC)
# Akifumi S. Tanabe (NRIFS)
# Charlie Taylor    (UF)
#
#
# Alignment has 23487 distinct alignment patterns
#
# Proportion of gaps and completely undetermined characters in this alignment: 3.33%
#
# RAxML rapid bootstrapping and subsequent ML search
#
# Using 1 distinct models/data partitions with joint branch length optimization
#
#
#
# Executing 100 rapid bootstrap inferences and thereafter a thorough ML search
#
# All free model parameters will be estimated by RAxML
# GAMMA model of rate heterogeneity, ML estimate of alpha-parameter
#
# GAMMA Model parameters will be estimated up to an accuracy of 0.1000000000 Log Likelihood units
#
# Partition: 0
# Alignment Patterns: 23487
# Name: No Name Provided
# DataType: DNA
# Substitution Matrix: GTR
#
#
#
#
# RAxML was called as follows:
#
# raxmlHPC-PTHREADS -T 6 -f a -m GTRGAMMA -p 53243 -x 72341 -s ../pan/core_gene_alignment.aln -N 100 -n testrapid.tree
#
#
#
# Time for BS model parameter optimization 3.269915
# Bootstrap[0]: Time 5.990383 seconds, bootstrap likelihood -3926754.093899, best rearrangement setting 5
# Bootstrap[1]: Time 2.594129 seconds, bootstrap likelihood -3928344.406823, best rearrangement setting 11
# Bootstrap[2]: Time 2.201109 seconds, bootstrap likelihood -3929830.658544, best rearrangement setting 10
# Bootstrap[3]: Time 2.193909 seconds, bootstrap likelihood -3925449.096489, best rearrangement setting 13
# Bootstrap[4]: Time 2.471751 seconds, bootstrap likelihood -3933626.608091, best rearrangement setting 14
# Bootstrap[5]: Time 2.621192 seconds, bootstrap likelihood -3924567.574418, best rearrangement setting 6
# Bootstrap[6]: Time 2.574977 seconds, bootstrap likelihood -3938517.805997, best rearrangement setting 12
# Bootstrap[7]: Time 2.888768 seconds, bootstrap likelihood -3926562.789218, best rearrangement setting 9
# Bootstrap[95]: Time 1.836153 seconds, bootstrap likelihood -3931634.692567, best rearrangement setting 12
# Bootstrap[96]: Time 1.838218 seconds, bootstrap likelihood -3925221.760122, best rearrangement setting 7
# Bootstrap[97]: Time 1.821651 seconds, bootstrap likelihood -3928977.451105, best rearrangement setting 10
# Bootstrap[98]: Time 1.831250 seconds, bootstrap likelihood -3931978.680967, best rearrangement setting 8
# Bootstrap[99]: Time 1.741066 seconds, bootstrap likelihood -3928858.393218, best rearrangement setting 5
#
#
# Overall Time for 100 Rapid Bootstraps 222.330325 seconds
# Average Time per Rapid Bootstrap 2.223303 seconds
#
# Starting ML Search ...
#
# Fast ML optimization finished
#
# Fast ML search Time: 201.361058 seconds
#
# Slow ML Search 0 Likelihood: -3928651.880277
# Slow ML Search 1 Likelihood: -3928651.880277
# Slow ML Search 2 Likelihood: -3928651.880259
# Slow ML Search 3 Likelihood: -3928651.880259
# Slow ML Search 4 Likelihood: -3928651.880285
# Slow ML Search 5 Likelihood: -3928651.880285
# Slow ML Search 6 Likelihood: -3928651.880260
# Slow ML Search 7 Likelihood: -3928651.880260
# Slow ML Search 8 Likelihood: -3928651.880298
# Slow ML Search 9 Likelihood: -3928651.880296
# Slow ML optimization finished
#
# Slow ML search Time: 130.089507 seconds
# Thorough ML search Time: 28.299973 seconds
#
# Final ML Optimization Likelihood: -3928651.880063
#
# Model Information:
#
# Model Parameters of Partition 0, Name: No Name Provided, Type of Data: DNA
# alpha: 0.020000
# Tree-Length: 0.118030
# rate A <-> C: 0.904967
# rate A <-> G: 4.202801
# rate A <-> T: 1.039622
# rate C <-> G: 0.606514
# rate C <-> T: 6.670158
# rate G <-> T: 1.000000
#
# freq pi(A): 0.235917
# freq pi(C): 0.248474
# freq pi(G): 0.277934
# freq pi(T): 0.237675
#
#
# ML search took 359.839195 secs or 0.099955 hours
#
# Combined Bootstrap and ML search took 582.177597 secs or 0.161716 hours
#
# Drawing Bootstrap Support Values on best-scoring ML tree ...
#
#
#
# Found 1 tree in File /mnt/d/Data/200404_trish/ecoli/raxml/RAxML_bestTree.testrapid.tree
#
#
#
# Found 1 tree in File /mnt/d/Data/200404_trish/ecoli/raxml/RAxML_bestTree.testrapid.tree
#
# Program execution info written to /mnt/d/Data/200404_trish/ecoli/raxml/RAxML_info.testrapid.tree
# All 100 bootstrapped trees written to: /mnt/d/Data/200404_trish/ecoli/raxml/RAxML_bootstrap.testrapid.tree
#
# Best-scoring ML tree written to: /mnt/d/Data/200404_trish/ecoli/raxml/RAxML_bestTree.testrapid.tree
#
# Best-scoring ML tree with support values written to: /mnt/d/Data/200404_trish/ecoli/raxml/RAxML_bipartitions.testrapid.tree
#
# Best-scoring ML tree with support values as branch labels written to: /mnt/d/Data/200404_trish/ecoli/raxml/RAxML_bipartitionsBranchLabels.testrapid.tree
#
# Overall execution time for full ML analysis: 582.209120 secs or 0.161725 hours or 0.006739 days
#
# /mnt/d/Data/200404_trish/ecoli
